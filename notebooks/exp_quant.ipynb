# %%
# plotting libraries
import matplotlib.pyplot as plt
from matplotlib import cm
import seaborn as sns

# data analysis libraries
import pandas as pd
import numpy as np

# general imports
from pathlib import Path

# auxiliary functions
import s3ts.analysis as aux

# %%
plt.rc('font', family='serif')
plt.rc('xtick', labelsize='medium')
plt.rc('ytick', labelsize='medium')

# %%
df = aux.load_data(Path("../results_synced/quant/"))
df.replace(np.NaN, 0).groupby(["arch", "dataset"]).count()
df
# Out:
#       dataset       arch  pretrained  fold_number  random_state  batch_size  \
# 0       Plane  ResNet_TS       False            3             0         128
# 1       Plane  ResNet_TS        True            3             0         128
# 2       Plane  ResNet_TS        True            3             0         128
# 3       Plane  ResNet_TS        True            3             0         128
# 4       Plane  ResNet_TS        True            3             0         128
# ..        ...        ...         ...          ...           ...         ...
# 350  GunPoint  ResNet_TS        True            0             0         128
# 351  GunPoint  ResNet_TS        True            0             0         128
# 352  GunPoint  ResNet_TS        True            0             0         128
# 353  GunPoint  ResNet_TS        True            0             0         128
# 354  GunPoint  ResNet_TS        True            0             0         128
#
#      window_size  target_val_acc  target_val_f1  target_val_auroc  ...  \
# 0              5        0.292969       0.292969          0.566119  ...
# 1              5        0.268555       0.268555          0.560540  ...
# 2              5        0.309082       0.309082          0.572924  ...
# 3              5        0.270508       0.270508          0.587319  ...
# 4              5        0.309570       0.309570          0.583532  ...
# ..           ...             ...            ...               ...  ...
# 350            5        0.576172       0.576172          0.508156  ...
# 351            5        0.565430       0.565430          0.574222  ...
# 352            5        0.570312       0.570312          0.538195  ...
# 353            5        0.561523       0.561523          0.639714  ...
# 354            5        0.591309       0.591309          0.609212  ...
#
#      nsamp_tra  nsamp_pre  nsamp_test pretrain_nquant pretrain_val_acc  \
# 0         6177          0        6033             NaN              NaN
# 1         6177      18273        6033             2.0         0.982585
# 2         6177      18273        6033             3.0         0.962728
# 3         6177      18273        6033             4.0         0.946615
# 4         6177      18273        6033             5.0         0.929362
# ..         ...        ...         ...             ...              ...
# 350       6135      18135        5985             5.0         0.948305
# 351       6135      18135        5985             6.0         0.894947
# 352       6135      18135        5985             7.0         0.906250
# 353       6135      18135        5985             8.0         0.869515
# 354       6135      18135        5985             9.0         0.827294
#
#      pretrain_val_f1  pretrain_val_auroc  \
# 0                NaN                 NaN
# 1           0.982585            0.990158
# 2           0.962728            0.989004
# 3           0.946615            0.987952
# 4           0.929362            0.985938
# ..               ...                 ...
# 350         0.948305            0.988950
# 351         0.894947            0.984623
# 352         0.906250            0.989419
# 353         0.869515            0.986357
# 354         0.827294            0.969541
#
#                                    pretrain_best_model  \
# 0                                                  NaN
# 1    training/exp/EXP_quant_f3.0_2023-03-10_02-36/l...
# 2    training/exp/EXP_quant_f3.1_2023-03-10_02-58/l...
# 3    training/exp/EXP_quant_f3.2_2023-03-10_03-20/l...
# 4    training/exp/EXP_quant_f3.3_2023-03-10_03-42/l...
# ..                                                 ...
# 350  training/exp/EXP_quant_f0.3_2023-03-09_19-15/l...
# 351  training/exp/EXP_quant_f0.4_2023-03-09_19-30/l...
# 352  training/exp/EXP_quant_f0.5_2023-03-09_19-46/l...
# 353  training/exp/EXP_quant_f0.6_2023-03-09_20-01/l...
# 354  training/exp/EXP_quant_f0.7_2023-03-09_20-17/l...
#
#                                     pretrain_train_csv  pretrain_nepochs
# 0                                                  NaN               NaN
# 1    training/exp/EXP_quant_f3.0_2023-03-10_02-36/l...              60.0
# 2    training/exp/EXP_quant_f3.1_2023-03-10_02-58/l...              60.0
# 3    training/exp/EXP_quant_f3.2_2023-03-10_03-20/l...              60.0
# 4    training/exp/EXP_quant_f3.3_2023-03-10_03-42/l...              60.0
# ..                                                 ...               ...
# 350  training/exp/EXP_quant_f0.3_2023-03-09_19-15/l...              60.0
# 351  training/exp/EXP_quant_f0.4_2023-03-09_19-30/l...              60.0
# 352  training/exp/EXP_quant_f0.5_2023-03-09_19-46/l...              60.0
# 353  training/exp/EXP_quant_f0.6_2023-03-09_20-01/l...              60.0
# 354  training/exp/EXP_quant_f0.7_2023-03-09_20-17/l...              60.0
#
# [355 rows x 26 columns]

# %%
dfp = aux.EXP_quant_preprocessing(df)
dfp
# Out:
#          arch dataset  pretrain_nquant  target_val_acc_mean  \
# 0     CNN_DFS  Coffee              0.0             0.558398
# 1     CNN_DFS  Coffee              3.0             0.698633
# 2     CNN_DFS  Coffee              5.0             0.606445
# 3     CNN_DFS  Coffee              7.0             0.616602
# 4     CNN_DFS  Coffee              9.0             0.649414
# ..        ...     ...              ...                  ...
# 72  ResNet_TS   Plane              5.0             0.294043
# 73  ResNet_TS   Plane              6.0             0.297754
# 74  ResNet_TS   Plane              7.0             0.285547
# 75  ResNet_TS   Plane              8.0             0.300195
# 76  ResNet_TS   Plane              9.0             0.294531
#
#     target_val_f1_mean  target_val_auroc_mean  target_test_acc_mean  \
# 0             0.558398               0.551101              0.498466
# 1             0.698633               0.736102              0.567489
# 2             0.606445               0.644517              0.525891
# 3             0.616602               0.637948              0.503399
# 4             0.649414               0.660143              0.528339
# ..                 ...                    ...                   ...
# 72            0.294043               0.574029              0.372174
# 73            0.297754               0.570544              0.378856
# 74            0.285547               0.558284              0.362633
# 75            0.300195               0.568679              0.381150
# 76            0.294531               0.579190              0.370612
#
#     target_test_f1_mean  target_test_auroc_mean  pretrain_val_acc_mean  ...  \
# 0              0.498466                0.477673               0.000000  ...
# 1              0.567489                0.569981               0.946946  ...
# 2              0.525891                0.534541               0.873384  ...
# 3              0.503399                0.501050               0.868854  ...
# 4              0.528339                0.515091               0.703768  ...
# ..                  ...                     ...                    ...  ...
# 72             0.372174                0.702039               0.926888  ...
# 73             0.378856                0.701142               0.915951  ...
# 74             0.362633                0.689036               0.897819  ...
# 75             0.381150                0.699356               0.880990  ...
# 76             0.370612                0.703580               0.864909  ...
#
#     pretrain_val_auroc_mean  target_val_acc_std  target_val_f1_std  \
# 0                  0.000000            0.081867           0.081867
# 1                  0.990531            0.083328           0.083328
# 2                  0.962202            0.077106           0.077106
# 3                  0.973639            0.104363           0.104363
# 4                  0.887161            0.119890           0.119890
# ..                      ...                 ...                ...
# 72                 0.983898            0.024675           0.024675
# 73                 0.982733            0.016789           0.016789
# 74                 0.977296            0.019010           0.019010
# 75                 0.974761            0.015857           0.015857
# 76                 0.970766            0.020526           0.020526
#
#     target_val_auroc_std  target_test_acc_std  target_test_f1_std  \
# 0               0.044085             0.042378            0.042378
# 1               0.059622             0.035110            0.035110
# 2               0.053235             0.038666            0.038666
# 3               0.117651             0.030193            0.030193
# 4               0.143893             0.041506            0.041506
# ..                   ...                  ...                 ...
# 72              0.019189             0.022861            0.022861
# 73              0.009052             0.020016            0.020016
# 74              0.004916             0.028333            0.028333
# 75              0.012521             0.027203            0.027203
# 76              0.012441             0.027264            0.027264
#
#     target_test_auroc_std  pretrain_val_acc_std  pretrain_val_f1_std  \
# 0                0.052575              0.000000             0.000000
# 1                0.039737              0.005338             0.005338
# 2                0.037598              0.001764             0.001764
# 3                0.055481              0.014015             0.014015
# 4                0.050789              0.069359             0.069359
# ..                    ...                   ...                  ...
# 72               0.016595              0.003044             0.003044
# 73               0.015287              0.001503             0.001503
# 74               0.009477              0.004847             0.004847
# 75               0.019838              0.004004             0.004004
# 76               0.013494              0.003843             0.003843
#
#     pretrain_val_auroc_std
# 0                 0.000000
# 1                 0.002437
# 2                 0.005063
# 3                 0.004517
# 4                 0.063851
# ..                     ...
# 72                0.002250
# 73                0.001647
# 74                0.000427
# 75                0.001859
# 76                0.003359
#
# [77 rows x 21 columns]

# %%
dfpb = aux.EXP_quant_set_baselines(dfp)
dfpb
# Out:
#          arch   dataset  pretrain_nquant target_val_acc_mean  \
# 0     CNN_DFS    Coffee              3.0            0.140234
# 1     CNN_DFS    Coffee              5.0            0.048047
# 2     CNN_DFS    Coffee              7.0            0.058203
# 3     CNN_DFS    Coffee              9.0            0.091016
# 4     CNN_DFS  GunPoint              2.0            0.048828
# ..        ...       ...              ...                 ...
# 63  ResNet_TS     Plane              5.0           -0.001855
# 64  ResNet_TS     Plane              6.0            0.001855
# 65  ResNet_TS     Plane              7.0           -0.010352
# 66  ResNet_TS     Plane              8.0            0.004297
# 67  ResNet_TS     Plane              9.0           -0.001367
#
#    target_val_f1_mean target_val_auroc_mean target_test_acc_mean  \
# 0            0.140234              0.185001             0.069023
# 1            0.048047              0.093416             0.027425
# 2            0.058203              0.086848             0.004933
# 3            0.091016              0.109043             0.029873
# 4            0.048828              0.049806             0.007965
# ..                ...                   ...                  ...
# 63          -0.001855               0.00174             0.007181
# 64           0.001855             -0.001746             0.013863
# 65          -0.010352             -0.014005             -0.00236
# 66           0.004297              -0.00361             0.016157
# 67          -0.001367              0.006901             0.005618
#
#    target_test_f1_mean target_test_auroc_mean  target_val_acc_std  \
# 0             0.069023               0.092308            0.083328
# 1             0.027425               0.056868            0.077106
# 2             0.004933               0.023377            0.104363
# 3             0.029873               0.037418            0.119890
# 4             0.007965               0.015675            0.122225
# ..                 ...                    ...                 ...
# 63            0.007181               0.005326            0.024675
# 64            0.013863               0.004429            0.016789
# 65            -0.00236              -0.007677            0.019010
# 66            0.016157               0.002643            0.015857
# 67            0.005618               0.006867            0.020526
#
#     target_val_f1_std  target_val_auroc_std  target_test_acc_std  \
# 0            0.083328              0.059622             0.035110
# 1            0.077106              0.053235             0.038666
# 2            0.104363              0.117651             0.030193
# 3            0.119890              0.143893             0.041506
# 4            0.122225              0.098366             0.091150
# ..                ...                   ...                  ...
# 63           0.024675              0.019189             0.022861
# 64           0.016789              0.009052             0.020016
# 65           0.019010              0.004916             0.028333
# 66           0.015857              0.012521             0.027203
# 67           0.020526              0.012441             0.027264
#
#     target_test_f1_std  target_test_auroc_std
# 0             0.035110               0.039737
# 1             0.038666               0.037598
# 2             0.030193               0.055481
# 3             0.041506               0.050789
# 4             0.091150               0.077544
# ..                 ...                    ...
# 63            0.022861               0.016595
# 64            0.020016               0.015287
# 65            0.028333               0.009477
# 66            0.027203               0.019838
# 67            0.027264               0.013494
#
# [68 rows x 15 columns]

# %%
fig = plt.figure(figsize=[20,8])
gs = fig.add_gridspec(2, 6, left=0.025, right=0.48, 
    wspace=0., hspace=0.12)

axes: dict[str, plt.Axes] = {
    "RNN_TS": fig.add_subplot(gs[0,0:2]),
    "CNN_TS": fig.add_subplot(gs[0,2:4]),
    "ResNet_TS": fig.add_subplot(gs[0,4:6]),
    "CNN_DFS": fig.add_subplot(gs[1,0:3]),
    "ResNet_DFS": fig.add_subplot(gs[1,3:6]),
}

right = ["RNN_TS", "CNN_DFS"]

colors = {
    "GunPoint": "blue",
    "Coffee": "red",
    "PowerCons": "purple",
    "Plane": "green",
}

metric = "acc"

for arch in axes:
    
    ax = axes[arch]
    ax.set_ylim(-0.10, 0.15)
    ax.set_xlim(1.5,9.5)
    ax.set_xticks(np.arange(2,10))

    ax.set_ylim(-15, 15)
    ax.set_yticks([-15, -10, -5, 0, 5, 10, 15])
    ax.grid(axis="y")

    if "TS" in arch:
        ax.set_ylim(-10, 10)
        ax.set_yticks([-10, -5, 0, 5, 10])

    if arch not in right:
        ax.set_yticklabels([])

    ax.annotate(arch, (0.05, 0.05), xycoords='axes fraction', va='center')

for (arch, dataset), dfg in dfpb.groupby(["arch", "dataset"]):
    axes[arch].errorbar(dfg[f"pretrain_nquant"], dfg[f"target_val_{metric}_mean"]*100, 
        #yerr=dfg[f"target_val_{metric}_std"]
        capsize=10, c=colors[dataset], linewidth=3, marker="x")

fig.text(0,0.5, s= metric +  " abs %", rotation="vertical", ha="center", va="center")
fig.text(0.5,0, s= "number of quantiles", rotation="vertical", ha="center", va="center")
# Out:
# Text(0, 0.5, 'acc abs %')
