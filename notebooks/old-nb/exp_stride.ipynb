# %%
# plotting libraries
import matplotlib.pyplot as plt
from matplotlib import cm
import seaborn as sns

# data analysis libraries
import pandas as pd
import numpy as np

# general imports
from pathlib import Path

# auxiliary functions
import s3ts.analysis as aux

# %%
# plt.rc('font', family='serif')
# plt.rc('xtick', labelsize='medium')
# plt.rc('ytick', labelsize='medium')

# %%
df = aux.load_data(Path("../results_synced/stride/"))
df
# Out:
#       dataset        arch  pretrained  fold_number  random_state  batch_size  \
# 0       Trace  ResNet_DFS       False            1             0         128
# 1       Trace  ResNet_DFS        True            1             0         128
# 2       Trace  ResNet_DFS       False            1             0         128
# 3       Trace  ResNet_DFS        True            1             0         128
# 4       Trace  ResNet_DFS       False            1             0         128
# ..        ...         ...         ...          ...           ...         ...
# 595  GunPoint     CNN_DFS        True            3             0         128
# 596  GunPoint     CNN_DFS       False            3             0         128
# 597  GunPoint     CNN_DFS        True            3             0         128
# 598  GunPoint     CNN_DFS       False            3             0         128
# 599  GunPoint     CNN_DFS        True            3             0         128
#
#      window_length  window_stride  target_val_acc  target_val_f1  ...  \
# 0                5              1        0.374479       0.374479  ...
# 1                5              1        0.462240       0.462240  ...
# 2                5              2        0.460417       0.460417  ...
# 3                5              2        0.370573       0.370573  ...
# 4                5              3        0.439844       0.439844  ...
# ..             ...            ...             ...            ...  ...
# 595              5              3        0.600098       0.600098  ...
# 596              5              4        0.692383       0.692383  ...
# 597              5              4        0.674805       0.674805  ...
# 598              5              5        0.664551       0.664551  ...
# 599              5              5        0.707520       0.707520  ...
#
#                                       target_train_csv  nsamp_tra  nsamp_pre  \
# 0    training/EXP_stride_f1.0_base_2023-03-16_13-39...      11260          0
# 1    training/EXP_stride_f1.0_2023-03-16_15-42/logs...      11260      33260
# 2    training/EXP_stride_f1.1_base_2023-03-16_20-46...      11245          0
# 3    training/EXP_stride_f1.1_2023-03-16_22-52/logs...      11245      33245
# 4    training/EXP_stride_f1.2_base_2023-03-17_04-04...      11230          0
# ..                                                 ...        ...        ...
# 595  training/EXP_stride_f3.2_2023-03-16_15-00/logs...       6105      18105
# 596  training/EXP_stride_f3.3_base_2023-03-16_15-23...       6090          0
# 597  training/EXP_stride_f3.3_2023-03-16_15-34/logs...       6090      18090
# 598  training/EXP_stride_f3.4_base_2023-03-16_15-58...       6075          0
# 599  training/EXP_stride_f3.4_2023-03-16_16-09/logs...       6075      18075
#
#      nsamp_test pretrain_val_mse pretrain_val_r2  \
# 0         10985              NaN             NaN
# 1         10985         0.284317        0.919347
# 2         10970              NaN             NaN
# 3         10970         0.295644        0.912795
# 4         10955              NaN             NaN
# ..          ...              ...             ...
# 595        5955         0.109927        0.987760
# 596        5940              NaN             NaN
# 597        5940         0.116305        0.986318
# 598        5925              NaN             NaN
# 599        5925         0.120109        0.985486
#
#                                    pretrain_best_model  \
# 0                                                  NaN
# 1    training/EXP_stride_f1.0_2023-03-16_15-42/logs...
# 2                                                  NaN
# 3    training/EXP_stride_f1.1_2023-03-16_22-52/logs...
# 4                                                  NaN
# ..                                                 ...
# 595  training/EXP_stride_f3.2_2023-03-16_15-00/logs...
# 596                                                NaN
# 597  training/EXP_stride_f3.3_2023-03-16_15-34/logs...
# 598                                                NaN
# 599  training/EXP_stride_f3.4_2023-03-16_16-09/logs...
#
#                                     pretrain_train_csv  target_nepochs  \
# 0                                                  NaN              41
# 1    training/EXP_stride_f1.0_2023-03-16_15-42/logs...             109
# 2                                                  NaN              84
# 3    training/EXP_stride_f1.1_2023-03-16_22-52/logs...              44
# 4                                                  NaN              44
# ..                                                 ...             ...
# 595  training/EXP_stride_f3.2_2023-03-16_15-00/logs...              81
# 596                                                NaN             118
# 597  training/EXP_stride_f3.3_2023-03-16_15-34/logs...             113
# 598                                                NaN             119
# 599  training/EXP_stride_f3.4_2023-03-16_16-09/logs...              54
#
#      pretrain_nepochs
# 0                 NaN
# 1                  54
# 2                 NaN
# 3                  57
# 4                 NaN
# ..                ...
# 595                57
# 596               NaN
# 597                59
# 598               NaN
# 599                58
#
# [600 rows x 25 columns]

# %%
dfp = df.groupby(["dataset", "arch", "window_stride", "pretrained"])[
    ["target_val_acc", "target_test_acc", "pretrain_val_r2"]
    ].mean().reset_index()
dfp
# Out:
#     dataset        arch  window_stride  pretrained  target_val_acc  \
# 0    Coffee     CNN_DFS              1       False        0.527500
# 1    Coffee     CNN_DFS              1        True        0.658906
# 2    Coffee     CNN_DFS              2       False        0.536719
# 3    Coffee     CNN_DFS              2        True        0.653438
# 4    Coffee     CNN_DFS              3       False        0.591562
# ..      ...         ...            ...         ...             ...
# 115   Trace  ResNet_DFS              3        True        0.475990
# 116   Trace  ResNet_DFS              4       False        0.450781
# 117   Trace  ResNet_DFS              4        True        0.509062
# 118   Trace  ResNet_DFS              5       False        0.463125
# 119   Trace  ResNet_DFS              5        True        0.486042
#
#      target_test_acc  pretrain_val_r2
# 0           0.484901              NaN
# 1           0.564488         0.977534
# 2           0.493414              NaN
# 3           0.577599         0.975123
# 4           0.528691              NaN
# ..               ...              ...
# 115         0.444485         0.948960
# 116         0.403787              NaN
# 117         0.447445         0.956458
# 118         0.430790              NaN
# 119         0.443088         0.954154
#
# [120 rows x 7 columns]

# %%
data = df.copy()
data["target_test_acc"] = 100*data["target_test_acc"]
data["target_val_acc"] = 100*data["target_val_acc"]
data["xd"] = data["pretrained"].replace({True: "(Pretrained)", False: "(Default)"})
data["arch"] = data["arch"].str.replace("_DFS", " ")
data["hue"] = data["arch"] + " " + data["xd"]
data.sort_values(["hue", "dataset"], inplace=True)

sns.set_theme()
sns.set_style("whitegrid")
plt.rc('font', family='serif')
plt.rc('xtick', labelsize='small')
plt.rc('ytick', labelsize='small')
g = sns.catplot(data=data, x="window_stride", y="target_test_acc", hue="hue", col="dataset", #row="arch",# hue="pretrained",
                kind="bar",  height=4, aspect=1, margin_titles=True, legend=False, legend_out=False, palette="muted", #["blue", "green", "orange", "red"],
                errorbar="sd", col_wrap=3, sharex=False, sharey=True, facet_kws={"despine": False, "ylim": (30, 80),
                    "gridspec_kws": {}});

#g.despine()
g.set_titles(row_template="{row_name}", col_template="{col_name}")
g.set_ylabels("Test Accuracy (%)")
g.set_xlabels("Window Stride")
g.add_legend(adjust_subtitles=True, fontsize="x-small")
g.facet_axis(0,2).set_xlabel("")
g.facet_axis(0,3).set_xlabel("")
g.facet_axis(0,5).set_xlabel("");
plt.savefig("stride.pdf")

# %%
dfl = aux.load_data(Path("../results_synced/length/"))
dfl
# Out:
#       dataset        arch  pretrained  fold_number  random_state  batch_size  \
# 0    GunPoint     CNN_DFS       False            4             0         128
# 1    GunPoint     CNN_DFS        True            4             0         128
# 2    GunPoint     CNN_DFS       False            4             0         128
# 3    GunPoint     CNN_DFS        True            4             0         128
# 4    GunPoint     CNN_DFS       False            4             0         128
# ..        ...         ...         ...          ...           ...         ...
# 469     Trace  ResNet_DFS       False            0             0         128
# 470     Trace  ResNet_DFS        True            0             0         128
# 471     Trace  ResNet_DFS       False            0             0         128
# 472     Trace  ResNet_DFS        True            0             0         128
# 473     Trace  ResNet_DFS       False            0             0         128
#
#      window_length  window_stride  target_val_acc  target_val_f1  ...  \
# 0               10              1        0.778320       0.778320  ...
# 1               10              1        0.750488       0.750488  ...
# 2               15              1        0.732910       0.732910  ...
# 3               15              1        0.747070       0.747070  ...
# 4               20              1        0.687012       0.687012  ...
# ..             ...            ...             ...            ...  ...
# 469             15              1        0.409115       0.409115  ...
# 470             15              1        0.465885       0.465885  ...
# 471             20              1        0.414062       0.414062  ...
# 472             20              1        0.474219       0.474219  ...
# 473             25              1        0.408333       0.408333  ...
#
#                                       target_train_csv  nsamp_tra  nsamp_pre  \
# 0    training/EXP_length_f4.0_base_2023-03-17_20-39...       6120          0
# 1    training/EXP_length_f4.0_2023-03-17_20-51/logs...       6120      18120
# 2    training/EXP_length_f4.1_base_2023-03-17_21-18...       6105          0
# 3    training/EXP_length_f4.1_2023-03-17_21-33/logs...       6105      18105
# 4    training/EXP_length_f4.2_base_2023-03-17_22-08...       6090          0
# ..                                                 ...        ...        ...
# 469  training/EXP_length_f0.1_base_2023-03-18_04-49...      11230          0
# 470  training/EXP_length_f0.1_2023-03-18_11-23/logs...      11230      33230
# 471  training/EXP_length_f0.2_base_2023-03-19_01-13...      11215          0
# 472  training/EXP_length_f0.2_2023-03-19_07-03/logs...      11215      33215
# 473  training/EXP_length_f0.3_base_2023-03-19_21-31...      11200          0
#
#      nsamp_test pretrain_val_mse pretrain_val_r2  \
# 0          5970              NaN             NaN
# 1          5970         0.098839        0.990225
# 2          5955              NaN             NaN
# 3          5955         0.124697        0.984422
# 4          5940              NaN             NaN
# ..          ...              ...             ...
# 469       10955              NaN             NaN
# 470       10955         0.205616        0.957804
# 471       10940              NaN             NaN
# 472       10940         0.149851        0.977586
# 473       10925              NaN             NaN
#
#                                    pretrain_best_model  \
# 0                                                  NaN
# 1    training/EXP_length_f4.0_2023-03-17_20-51/logs...
# 2                                                  NaN
# 3    training/EXP_length_f4.1_2023-03-17_21-33/logs...
# 4                                                  NaN
# ..                                                 ...
# 469                                                NaN
# 470  training/EXP_length_f0.1_2023-03-18_11-23/logs...
# 471                                                NaN
# 472  training/EXP_length_f0.2_2023-03-19_07-03/logs...
# 473                                                NaN
#
#                                     pretrain_train_csv  target_nepochs  \
# 0                                                  NaN             113
# 1    training/EXP_length_f4.0_2023-03-17_20-51/logs...             116
# 2                                                  NaN             106
# 3    training/EXP_length_f4.1_2023-03-17_21-33/logs...              85
# 4                                                  NaN             116
# ..                                                 ...             ...
# 469                                                NaN              87
# 470  training/EXP_length_f0.1_2023-03-18_11-23/logs...              83
# 471                                                NaN              57
# 472  training/EXP_length_f0.2_2023-03-19_07-03/logs...              60
# 473                                                NaN              27
#
#      pretrain_nepochs
# 0                 NaN
# 1                  59
# 2                 NaN
# 3                  59
# 4                 NaN
# ..                ...
# 469               NaN
# 470                54
# 471               NaN
# 472                57
# 473               NaN
#
# [474 rows x 25 columns]

# %%
dflp = dfl.groupby(["dataset", "arch", "window_length", "pretrained"])[["target_val_acc", "target_test_acc", "pretrain_val_r2"]].mean().reset_index()
dflp
# Out:
#    dataset        arch  window_length  pretrained  target_val_acc  \
# 0   Coffee     CNN_DFS             10       False        0.570781
# 1   Coffee     CNN_DFS             10        True        0.653750
# 2   Coffee     CNN_DFS             15       False        0.591094
# 3   Coffee     CNN_DFS             15        True        0.572031
# 4   Coffee     CNN_DFS             20       False        0.603993
# ..     ...         ...            ...         ...             ...
# 91   Trace  ResNet_DFS             15        True        0.472083
# 92   Trace  ResNet_DFS             20       False        0.400156
# 93   Trace  ResNet_DFS             20        True        0.448763
# 94   Trace  ResNet_DFS             25       False        0.392535
# 95   Trace  ResNet_DFS             25        True        0.406641
#
#     target_test_acc  pretrain_val_r2
# 0          0.522486              NaN
# 1          0.593915         0.984615
# 2          0.526522              NaN
# 3          0.516226         0.977063
# 4          0.521890              NaN
# ..              ...              ...
# 91         0.424596         0.910143
# 92         0.385570              NaN
# 93         0.408892         0.911126
# 94         0.371691              NaN
# 95         0.372381         0.887820
#
# [96 rows x 7 columns]

# %%
data = dfl.copy()
data["target_test_acc"] = 100*data["target_test_acc"]
data["xd"] = data["pretrained"].replace({True: "(Pretrained)", False: "(Default)"})
data["arch"] = data["arch"].str.replace("_DFS", " ")
data["hue"] = data["arch"] + " " + data["xd"]
data.sort_values(["hue", "dataset"], inplace=True)

sns.set_theme()
sns.set_style("whitegrid")
plt.rc('font', family='serif')
plt.rc('xtick', labelsize='small')
plt.rc('ytick', labelsize='small')
g = sns.catplot(data=data, x="window_length", y="target_test_acc", hue="hue", col="dataset", #row="arch",# hue="pretrained",
                kind="bar",  height=4, aspect=1, margin_titles=True, legend=False, legend_out=False, palette="muted", #["blue", "green", "orange", "red"],
                errorbar="sd", col_wrap=3, sharex=False, sharey=True, facet_kws={"despine": False, "ylim": (30, 80),
                    "gridspec_kws": {}});

#g.despine()
g.set_titles(row_template="{row_name}", col_template="{col_name}")
g.set_ylabels("Test Accuracy (%)")
g.set_xlabels("Window Length")
g.add_legend(adjust_subtitles=True, fontsize="x-small")
g.facet_axis(0,2).set_xlabel("");
g.facet_axis(0,3).set_xlabel("");
g.facet_axis(0,5).set_xlabel("");
plt.savefig("length.pdf")

# %%
df = aux.load_data(Path("../results/"))
df["target_nepochs"] = df["target_nepochs"].astype(int)
df.groupby(["arch", "dataset", "approach"])[["target_test_acc", "target_test_auroc", "target_nepochs"]].mean()
# Out:
#                            target_test_acc  target_test_auroc  target_nepochs
# arch    dataset  approach
# CNN_DFS GunPoint linear           0.484035            0.36453             0.0

# %%
dfr = aux.load_data(Path("../results_synced/ratio"))
dfr
# Out:
#                dataset        arch  pretrained  fold_number  random_state  \
# 0                Trace     CNN_DFS       False            2             0
# 1                Trace     CNN_DFS        True            2             0
# 2                Trace     CNN_DFS        True            2             0
# 3                Trace     CNN_DFS        True            2             0
# 4                Trace     CNN_DFS        True            2             0
# ...                ...         ...         ...          ...           ...
# 1545             Plane  ResNet_DFS        True            1             0
# 1546             Plane  ResNet_DFS        True            1             0
# 1547             Plane  ResNet_DFS        True            1             0
# 1548             Plane  ResNet_DFS        True            1             0
# 1549  SyntheticControl     CNN_DFS       False            3             0
#
#       batch_size  window_length  window_stride  target_val_acc  target_val_f1  \
# 0            128              5              1        0.535156       0.535156
# 1            128              5              1        0.621094       0.621094
# 2            128              5              1        0.589844       0.589844
# 3            128              5              1        0.636719       0.636719
# 4            128              5              1        0.533854       0.533854
# ...          ...            ...            ...             ...            ...
# 1545         128              5              1        0.627441       0.627441
# 1546         128              5              1        0.623047       0.623047
# 1547         128              5              1        0.637207       0.637207
# 1548         128              5              1        0.638672       0.638672
# 1549         128              5              1        0.518229       0.518229
#
#       ...  nsamp_tra  nsamp_pre  nsamp_test  pretrain_val_mse pretrain_val_r2  \
# 0     ...       2251          0       10985               NaN             NaN
# 1     ...       2251       6652       10985          0.355210        0.874046
# 2     ...       2251      13304       10985          0.290784        0.916494
# 3     ...       2251      19956       10985          0.255052        0.936058
# 4     ...       2251      26608       10985          0.175883        0.969185
# ...   ...        ...        ...         ...               ...             ...
# 1545  ...       6177       7308        6033          0.097342        0.990350
# 1546  ...       6177      10963        6033          0.072150        0.994718
# 1547  ...       6177      14617        6033          0.073313        0.994553
# 1548  ...       6177      18273        6033          0.063028        0.995976
# 1549  ...       1449          0        7185               NaN             NaN
#
#                                     pretrain_best_model  \
# 0                                                   NaN
# 1     training/2023-03-21_00-01_EXP_ratio_CNN_DFS_Tr...
# 2     training/2023-03-21_00-15_EXP_ratio_CNN_DFS_Tr...
# 3     training/2023-03-21_00-36_EXP_ratio_CNN_DFS_Tr...
# 4     training/2023-03-21_01-03_EXP_ratio_CNN_DFS_Tr...
# ...                                                 ...
# 1545  training/2023-03-22_02-57_EXP_ratio_ResNet_DFS...
# 1546  training/2023-03-22_03-53_EXP_ratio_ResNet_DFS...
# 1547  training/2023-03-22_04-59_EXP_ratio_ResNet_DFS...
# 1548  training/2023-03-22_06-13_EXP_ratio_ResNet_DFS...
# 1549                                                NaN
#
#                                      pretrain_train_csv  approach  \
# 0                                                   NaN       NaN
# 1     training/2023-03-21_00-01_EXP_ratio_CNN_DFS_Tr...       NaN
# 2     training/2023-03-21_00-15_EXP_ratio_CNN_DFS_Tr...       NaN
# 3     training/2023-03-21_00-36_EXP_ratio_CNN_DFS_Tr...       NaN
# 4     training/2023-03-21_01-03_EXP_ratio_CNN_DFS_Tr...       NaN
# ...                                                 ...       ...
# 1545  training/2023-03-22_02-57_EXP_ratio_ResNet_DFS...       NaN
# 1546  training/2023-03-22_03-53_EXP_ratio_ResNet_DFS...       NaN
# 1547  training/2023-03-22_04-59_EXP_ratio_ResNet_DFS...       NaN
# 1548  training/2023-03-22_06-13_EXP_ratio_ResNet_DFS...       NaN
# 1549                                                NaN      lstm
#
#       target_nepochs  pretrain_nepochs
# 0                111               NaN
# 1                105                56
# 2                 95                56
# 3                 47                56
# 4                 38                59
# ...              ...               ...
# 1545              89                56
# 1546             115                59
# 1547             115                59
# 1548             100                55
# 1549             119               NaN
#
# [1550 rows x 26 columns]

# %%
def xd(df: pd.DataFrame):

    pcts_tra = [0.2, 0.4, 0.6, 0.8, 1]
    pcts_pre = [0, 0.2, 0.4, 0.6, 0.8, 1]

    dfs = []
    for (dataset, arch), dfg in df.groupby(["dataset", "arch"]):

        if dataset in ["Coffee"]:
            dfg = aux.__fix_close_values(dfg, "nsamp_pre")

        dfg["nsamp_tra_ratio"] = dfg["nsamp_tra"].replace(
            to_replace={n: pcts_tra[i] for i, n in enumerate(dfg["nsamp_tra"].unique())})
        
        dfg["nsamp_pre_ratio"] = dfg["nsamp_pre"].replace(
            to_replace={n: pcts_pre[i] for i, n in enumerate(dfg["nsamp_pre"].unique())})

        dfs.append(dfg)

    return pd.concat(dfs)


dfrb = xd(dfr)
dfrb
# Out:
#      dataset        arch  pretrained  fold_number  random_state  batch_size  \
# 153   Coffee     CNN_DFS       False            2             0         128
# 154   Coffee     CNN_DFS        True            2             0         128
# 155   Coffee     CNN_DFS        True            2             0         128
# 156   Coffee     CNN_DFS        True            2             0         128
# 157   Coffee     CNN_DFS        True            2             0         128
# ...      ...         ...         ...          ...           ...         ...
# 1514   Trace  ResNet_DFS       False            2             0         128
# 1515   Trace  ResNet_DFS        True            2             0         128
# 1516   Trace  ResNet_DFS        True            2             0         128
# 1517   Trace  ResNet_DFS        True            2             0         128
# 1518   Trace  ResNet_DFS        True            2             0         128
#
#       window_length  window_stride  target_val_acc  target_val_f1  ...  \
# 153               5              1        0.312500       0.312500  ...
# 154               5              1        0.687500       0.687500  ...
# 155               5              1        0.687500       0.687500  ...
# 156               5              1        0.312500       0.312500  ...
# 157               5              1        0.687500       0.687500  ...
# ...             ...            ...             ...            ...  ...
# 1514              5              1        0.350260       0.350260  ...
# 1515              5              1        0.347656       0.347656  ...
# 1516              5              1        0.536458       0.536458  ...
# 1517              5              1        0.378906       0.378906  ...
# 1518              5              1        0.412109       0.412109  ...
#
#       nsamp_test  pretrain_val_mse  pretrain_val_r2  \
# 153         3131               NaN              NaN
# 154         3131          0.354237         0.888054
# 155         3131          0.234377         0.948814
# 156         3131          0.204017         0.959156
# 157         3131          0.168785         0.972530
# ...          ...               ...              ...
# 1514       10985               NaN              NaN
# 1515       10985          0.356366         0.873225
# 1516       10985          0.413073         0.831514
# 1517       10985          0.234960         0.945737
# 1518       10985          0.196310         0.961611
#
#                                     pretrain_best_model  \
# 153                                                 NaN
# 154   training/2023-03-20_21-11_EXP_ratio_CNN_DFS_Co...
# 155   training/2023-03-20_21-20_EXP_ratio_CNN_DFS_Co...
# 156   training/2023-03-20_21-30_EXP_ratio_CNN_DFS_Co...
# 157   training/2023-03-20_21-42_EXP_ratio_CNN_DFS_Co...
# ...                                                 ...
# 1514                                                NaN
# 1515  training/2023-03-22_00-05_EXP_ratio_ResNet_DFS...
# 1516  training/2023-03-22_01-10_EXP_ratio_ResNet_DFS...
# 1517  training/2023-03-22_02-39_EXP_ratio_ResNet_DFS...
# 1518  training/2023-03-22_04-35_EXP_ratio_ResNet_DFS...
#
#                                      pretrain_train_csv approach  \
# 153                                                 NaN      NaN
# 154   training/2023-03-20_21-11_EXP_ratio_CNN_DFS_Co...      NaN
# 155   training/2023-03-20_21-20_EXP_ratio_CNN_DFS_Co...      NaN
# 156   training/2023-03-20_21-30_EXP_ratio_CNN_DFS_Co...      NaN
# 157   training/2023-03-20_21-42_EXP_ratio_CNN_DFS_Co...      NaN
# ...                                                 ...      ...
# 1514                                                NaN      NaN
# 1515  training/2023-03-22_00-05_EXP_ratio_ResNet_DFS...      NaN
# 1516  training/2023-03-22_01-10_EXP_ratio_ResNet_DFS...      NaN
# 1517  training/2023-03-22_02-39_EXP_ratio_ResNet_DFS...      NaN
# 1518  training/2023-03-22_04-35_EXP_ratio_ResNet_DFS...      NaN
#
#       target_nepochs  pretrain_nepochs  nsamp_tra_ratio  nsamp_pre_ratio
# 153                0               NaN              0.2              0.0
# 154                0                55              0.2              0.2
# 155                0                57              0.2              0.4
# 156                0                58              0.2              0.6
# 157                0                59              0.2              0.8
# ...              ...               ...              ...              ...
# 1514              60               NaN              0.4              0.0
# 1515               1                38              0.4              0.2
# 1516             116                39              0.4              0.4
# 1517              66                50              0.4              0.6
# 1518              11                58              0.4              0.8
#
# [1550 rows x 28 columns]

# %%
check = dfrb.groupby(["arch", "dataset", "nsamp_tra_ratio", "nsamp_pre_ratio"])[["pretrained"]].count()
check[check["pretrained"]<5]
dfrb = dfrb[dfrb["dataset"] != "SyntheticControl"]

# %%
data = dfrb[dfrb["arch"] == "CNN_DFS"].copy()
data["target_test_acc"] = 100*data["target_test_acc"]
#data["xd"] = data["pretrained"].replace({True: "(Pretrained)", False: "(Default)"})
data["arch"] = data["arch"].str.replace("_DFS", " ")
#data["hue"] = data["arch"] + " " + data["xd"]
#data.sort_values(["hue", "dataset"], inplace=True)

sns.set_theme()
sns.set_style("whitegrid")
plt.rc('font', family='serif')
plt.rc('xtick', labelsize='small')
plt.rc('ytick', labelsize='small')
g = sns.catplot(data=data, x="nsamp_tra_ratio", y="target_test_acc", hue="nsamp_pre_ratio", col="dataset", #row="arch",# hue="pretrained",
                kind="bar",  height=4, aspect=1, margin_titles=True, legend=False, legend_out=False, palette="muted", #["blue", "green", "orange", "red"],
                errorbar="sd", col_wrap=3, sharex=False, sharey=True, facet_kws={"despine": False, "ylim": (15, 75),
                "gridspec_kws": {}});

#g.despine()
g.set_titles(row_template="{row_name}", col_template="{col_name}")
g.set_ylabels("Test Accuracy (%)")
g.set_xlabels("Train Sample Ratio")
g.add_legend(adjust_subtitles=True, fontsize="x-small");
# g.facet_axis(0,2).set_xlabel("");
# g.facet_axis(0,3).set_xlabel("");
# g.facet_axis(0,5).set_xlabel("");
plt.savefig("ratio_CNN.pdf")

# %%
data = dfrb[dfrb["arch"] == "ResNet_DFS"].copy()
data["target_test_acc"] = 100*data["target_test_acc"]
#data["xd"] = data["pretrained"].replace({True: "(Pretrained)", False: "(Default)"})
data["arch"] = data["arch"].str.replace("_DFS", " ")
#data["hue"] = data["arch"] + " " + data["xd"]
#data.sort_values(["hue", "dataset"], inplace=True)

sns.set_theme()
sns.set_style("whitegrid")
plt.rc('font', family='serif')
plt.rc('xtick', labelsize='small')
plt.rc('ytick', labelsize='small')
g = sns.catplot(data=data, x="nsamp_tra_ratio", y="target_test_acc", hue="nsamp_pre_ratio", col="dataset", #row="arch",# hue="pretrained",
                kind="bar",  height=4, aspect=1, margin_titles=True, legend=False, legend_out=False, palette="muted", #["blue", "green", "orange", "red"],
                errorbar="sd", col_wrap=3, sharex=False, sharey=True, facet_kws={"despine": False, "ylim": (15, 75),
                "gridspec_kws": {}});

#g.despine()
g.set_titles(row_template="{row_name}", col_template="{col_name}")
g.set_ylabels("Test Accuracy (%)")
g.set_xlabels("Train Sample Ratio")
g.add_legend(adjust_subtitles=True, fontsize="x-small");
# g.facet_axis(0,2).set_xlabel("");
# g.facet_axis(0,3).set_xlabel("");
# g.facet_axis(0,5).set_xlabel("");
plt.savefig("ratio_ResNet.pdf")
