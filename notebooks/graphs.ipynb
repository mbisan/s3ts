# %%
# plotting libraries
import matplotlib.pyplot as plt
from matplotlib import cm
import seaborn as sns

# data analysis libraries
import pandas as pd
import numpy as np

# general imports
from pathlib import Path

# auxiliary functions
import s3ts.analysis as aux

# %%
df = aux.load_data(Path("results_synced/ratio/"))
#df.groupby(["dataset", "arch", "nsamp_tra", "nsamp_pre"]).count()
#df = df[df["fold_number"] == 1]
#df[df["pretrained"]]["target_best_model"].str.split("/").str[6].str.removeprefix("epoch=").str.split("-").str[0].astype(int).hist()
df
# Out:
#        dataset       arch  pretrained  fold_number  random_state  batch_size  \
# 0     GunPoint  ResNet_TS       False            4             0         128
# 1     GunPoint  ResNet_TS        True            4             0         128
# 2     GunPoint  ResNet_TS        True            4             0         128
# 3     GunPoint  ResNet_TS        True            4             0         128
# 4     GunPoint  ResNet_TS        True            4             0         128
# ...        ...        ...         ...          ...           ...         ...
# 1098  GunPoint  ResNet_TS        True            3             0         128
# 1099  GunPoint  ResNet_TS        True            3             0         128
# 1100  GunPoint  ResNet_TS        True            3             0         128
# 1101  GunPoint  ResNet_TS        True            3             0         128
# 1102  GunPoint  ResNet_TS        True            3             0         128
#
#       window_size  target_val_acc  target_val_f1  target_val_auroc  ...  \
# 0               5        0.518229       0.518229          0.503552  ...
# 1               5        0.502604       0.502604          0.369496  ...
# 2               5        0.497396       0.497396          0.538775  ...
# 3               5        0.494792       0.494792          0.375771  ...
# 4               5        0.528646       0.528646          0.687410  ...
# ...           ...             ...            ...               ...  ...
# 1098            5        0.559082       0.559082          0.519742  ...
# 1099            5        0.541016       0.541016          0.512700  ...
# 1100            5        0.520020       0.520020          0.500444  ...
# 1101            5        0.576172       0.576172          0.579706  ...
# 1102            5        0.543457       0.543457          0.540552  ...
#
#       target_nepochs  nsamp_tra  nsamp_pre nsamp_test pretrain_val_acc  \
# 0                120       1227          0       5985              NaN
# 1                120       1227       3627       5985         0.960069
# 2                120       1227       7254       5985         0.959704
# 3                120       1227      10881       5985         0.965681
# 4                120       1227      14508       5985         0.957031
# ...              ...        ...        ...        ...              ...
# 1098             120       6135       3627       5985         0.891493
# 1099             120       6135       7254       5985         0.904605
# 1100             120       6135      10881       5985         0.937779
# 1101             120       6135      14508       5985         0.941406
# 1102             120       6135      18135       5985         0.944315
#
#       pretrain_val_f1  pretrain_val_auroc  \
# 0                 NaN                 NaN
# 1            0.960069            0.990953
# 2            0.959704            0.993323
# 3            0.965681            0.994463
# 4            0.957031            0.994946
# ...               ...                 ...
# 1098         0.891493            0.963834
# 1099         0.904605            0.982224
# 1100         0.937779            0.990147
# 1101         0.941406            0.990062
# 1102         0.944315            0.989825
#
#                                     pretrain_best_model  \
# 0                                                   NaN
# 1     training/exp/EXP_ratio_f4.0_2023-03-08_07-17/l...
# 2     training/exp/EXP_ratio_f4.0_2023-03-08_07-23/l...
# 3     training/exp/EXP_ratio_f4.0_2023-03-08_07-30/l...
# 4     training/exp/EXP_ratio_f4.0_2023-03-08_07-38/l...
# ...                                                 ...
# 1098  training/exp/EXP_ratio_f3.4_2023-03-08_06-17/l...
# 1099  training/exp/EXP_ratio_f3.4_2023-03-08_06-26/l...
# 1100  training/exp/EXP_ratio_f3.4_2023-03-08_06-36/l...
# 1101  training/exp/EXP_ratio_f3.4_2023-03-08_06-47/l...
# 1102  training/exp/EXP_ratio_f3.4_2023-03-08_06-59/l...
#
#                                      pretrain_train_csv  pretrain_nepochs
# 0                                                   NaN               NaN
# 1     training/exp/EXP_ratio_f4.0_2023-03-08_07-17/l...              60.0
# 2     training/exp/EXP_ratio_f4.0_2023-03-08_07-23/l...              60.0
# 3     training/exp/EXP_ratio_f4.0_2023-03-08_07-30/l...              60.0
# 4     training/exp/EXP_ratio_f4.0_2023-03-08_07-38/l...              60.0
# ...                                                 ...               ...
# 1098  training/exp/EXP_ratio_f3.4_2023-03-08_06-17/l...              60.0
# 1099  training/exp/EXP_ratio_f3.4_2023-03-08_06-26/l...              60.0
# 1100  training/exp/EXP_ratio_f3.4_2023-03-08_06-36/l...              60.0
# 1101  training/exp/EXP_ratio_f3.4_2023-03-08_06-47/l...              60.0
# 1102  training/exp/EXP_ratio_f3.4_2023-03-08_06-59/l...              60.0
#
# [1103 rows x 25 columns]

# %%
dfr = aux.EXP_ratio_preprocessing(df)
dfr
# Out:
#           arch    dataset  nsamp_pre  nsamp_tra  pretrain_val_acc_mean  \
# 0      CNN_DFS     Coffee          0        683                    NaN
# 1      CNN_DFS     Coffee       1998        683               0.812500
# 2      CNN_DFS     Coffee       3997        683               0.847266
# 3      CNN_DFS     Coffee       5996        683               0.868896
# 4      CNN_DFS     Coffee       7995        683               0.867001
# ..         ...        ...        ...        ...                    ...
# 280  ResNet_TS  PowerCons          0       6298                    NaN
# 281  ResNet_TS  PowerCons       6246       6298               0.756348
# 282  ResNet_TS  PowerCons      12492       6298               0.811035
# 283  ResNet_TS  PowerCons      18739       6298               0.797034
# 284  ResNet_TS  PowerCons      24985       6298               0.771995
#
#      pretrain_val_acc_std  pretrain_val_auroc_mean  pretrain_val_auroc_std  \
# 0                     NaN                      NaN                     NaN
# 1                0.017678                 0.943704                0.021259
# 2                0.019335                 0.937462                0.023213
# 3                0.007251                 0.952854                0.000227
# 4                0.004472                 0.960240                0.003600
# ..                    ...                      ...                     ...
# 280                   NaN                      NaN                     NaN
# 281                   NaN                 0.919529                     NaN
# 282                   NaN                 0.942490                     NaN
# 283                   NaN                 0.923224                     NaN
# 284                   NaN                 0.933094                     NaN
#
#      pretrain_val_f1_mean  pretrain_val_f1_std  ...  target_test_auroc_mean  \
# 0                     NaN                  NaN  ...                0.399082
# 1                0.812500             0.017678  ...                0.476540
# 2                0.847266             0.019335  ...                0.477514
# 3                0.868896             0.007251  ...                0.486374
# 4                0.867001             0.004472  ...                0.478362
# ..                    ...                  ...  ...                     ...
# 280                   NaN                  NaN  ...                0.627511
# 281              0.756348                  NaN  ...                0.700194
# 282              0.811035                  NaN  ...                0.645328
# 283              0.797034                  NaN  ...                0.699925
# 284              0.771995                  NaN  ...                0.598814
#
#      target_test_auroc_std  target_test_f1_mean  target_test_f1_std  \
# 0                 0.021400             0.437988            0.011739
# 1                 0.042504             0.512370            0.039591
# 2                 0.006953             0.508777            0.011987
# 3                 0.031603             0.518417            0.037944
# 4                 0.031873             0.487442            0.014537
# ..                     ...                  ...                 ...
# 280                    NaN             0.629297                 NaN
# 281                    NaN             0.637988                 NaN
# 282                    NaN             0.635059                 NaN
# 283                    NaN             0.627051                 NaN
# 284                    NaN             0.514746                 NaN
#
#      target_val_acc_mean  target_val_acc_std  target_val_auroc_mean  \
# 0               0.312500            0.000000               0.000000
# 1               0.800781            0.016573               0.773828
# 2               0.765625            0.093913               0.752095
# 3               0.798828            0.002762               0.772195
# 4               0.710938            0.049718               0.773580
# ..                   ...                 ...                    ...
# 280             0.668457                 NaN               0.666156
# 281             0.696289                 NaN               0.753294
# 282             0.696289                 NaN               0.687335
# 283             0.687500                 NaN               0.759661
# 284             0.544922                 NaN               0.643268
#
#      target_val_auroc_std  target_val_f1_mean  target_val_f1_std
# 0                0.000000            0.312500           0.000000
# 1                0.023553            0.800781           0.016573
# 2                0.080805            0.765625           0.093913
# 3                0.079801            0.798828           0.002762
# 4                0.025412            0.710938           0.049718
# ..                    ...                 ...                ...
# 280                   NaN            0.668457                NaN
# 281                   NaN            0.696289                NaN
# 282                   NaN            0.696289                NaN
# 283                   NaN            0.687500                NaN
# 284                   NaN            0.544922                NaN
#
# [285 rows x 22 columns]

# %%
dfr["dataset"].unique()
# Out:
# array(['Coffee', 'GunPoint', 'PowerCons'], dtype=object)

# %%
plt.figure()

metric = "acc"
arch = "CNN_DFS"
dataset = "GunPoint"

colors = ["blue", "green", "purple", "orange", "red"]
fig, ax = plt.subplots(figsize=[12,8])
for i, (nsamp_pre, dfg) in enumerate(dfr[dfr["arch"] == arch][dfr["dataset"] == dataset].replace(np.NaN, 0).groupby("nsamp_tra")):
    # ax.plot(dfg["nsamp_pre"], dfg[f"target_test_{metric}_mean"], label=f'train_samp={dfg["nsamp_tra"].unique()[0]}', c=colors[i])
    ax.errorbar(dfg["nsamp_pre"], dfg[f"target_test_{metric}_mean"], yerr=dfg[f"target_test_{metric}_std"], 
                label=f'train_samp={dfg["nsamp_tra"].unique()[0]}', c=colors[i])
    ax.fill_between(dfg["nsamp_pre"], y1=dfg[f"target_test_{metric}_mean"]+dfg[f"target_test_{metric}_std"], 
        y2=dfg[f"target_test_{metric}_mean"]-dfg[f"target_test_{metric}_std"], alpha = 0.5, color=colors[i])
plt.legend()
plt.grid(True)
plt.xlabel("pretrain samples")
plt.ylabel(metric);
plt.show();
# Out:
#   Cell In[87], line 13
#     ax.fill_between(dfg["nsamp_pre"], y1=dfg[f"target_test_{metric}_mean"]+dfg[f"target_test_{metric}_std"],
#                    ^
# SyntaxError: '(' was never closed

# %%
dfrb = aux.EXP_ratio_set_baselines(dfr)
# dfrb[dfrb["nsamp_tra"]!=4908]["target_test_acc_mean"].max()
dfrb
# Out:
#           arch    dataset  nsamp_pre  nsamp_tra target_test_acc_mean  \
# 0      CNN_DFS     Coffee       1998        683             0.074382
# 1      CNN_DFS     Coffee       3997        683             0.070788
# 2      CNN_DFS     Coffee       5996        683             0.080429
# 3      CNN_DFS     Coffee       7995        683             0.049454
# 4      CNN_DFS     Coffee       9995        683             0.048002
# ..         ...        ...        ...        ...                  ...
# 232  ResNet_TS  PowerCons      31233       4198            -0.025098
# 233  ResNet_TS  PowerCons       6246       6298             0.008691
# 234  ResNet_TS  PowerCons      12492       6298             0.005762
# 235  ResNet_TS  PowerCons      18739       6298            -0.002246
# 236  ResNet_TS  PowerCons      24985       6298            -0.114551
#
#     target_test_acc_std target_test_auroc_mean target_test_auroc_std  \
# 0               0.05133               0.077458              0.063903
# 1              0.023726               0.078432              0.028353
# 2              0.049683               0.087292              0.053002
# 3              0.026276                0.07928              0.053272
# 4              0.013598               0.085886              0.027375
# ..                  ...                    ...                   ...
# 232                 NaN               0.049341                   NaN
# 233                 NaN               0.072683                   NaN
# 234                 NaN               0.017817                   NaN
# 235                 NaN               0.072414                   NaN
# 236                 NaN              -0.028697                   NaN
#
#     target_test_f1_mean target_test_f1_std target_val_acc_mean  \
# 0              0.074382            0.05133            0.488281
# 1              0.070788           0.023726            0.453125
# 2              0.080429           0.049683            0.486328
# 3              0.049454           0.026276            0.398438
# 4              0.048002           0.013598            0.357422
# ..                  ...                ...                 ...
# 232           -0.025098                NaN           -0.017756
# 233            0.008691                NaN            0.027832
# 234            0.005762                NaN            0.027832
# 235           -0.002246                NaN            0.019043
# 236           -0.114551                NaN           -0.123535
#
#     target_val_acc_std target_val_auroc_mean target_val_auroc_std  \
# 0             0.016573              0.773828             0.023553
# 1             0.093913              0.752095             0.080805
# 2             0.002762              0.772195             0.079801
# 3             0.049718               0.77358             0.025412
# 4             0.019335              0.745241             0.027923
# ..                 ...                   ...                  ...
# 232                NaN              0.074445                  NaN
# 233                NaN              0.087139                  NaN
# 234                NaN               0.02118                  NaN
# 235                NaN              0.093505                  NaN
# 236                NaN             -0.022888                  NaN
#
#     target_val_f1_mean target_val_f1_std
# 0             0.488281          0.016573
# 1             0.453125          0.093913
# 2             0.486328          0.002762
# 3             0.398438          0.049718
# 4             0.357422          0.019335
# ..                 ...               ...
# 232          -0.017756               NaN
# 233           0.027832               NaN
# 234           0.027832               NaN
# 235           0.019043               NaN
# 236          -0.123535               NaN
#
# [237 rows x 16 columns]

# %%
plt.figure()

#dfrb = dfrb[dfrb["nsamp_tra"] != 4908]

metric = "acc"
arch = "CNN_DFS"
dataset = "GunPoint"

dfrb_filt = dfrb[dfrb["arch"] == arch][dfrb["dataset"] == dataset].replace(np.NaN, 0)


colors = ["blue", "green", "purple", "orange", "red"]
fig, ax = plt.subplots(figsize=[12,8])
for i, (nsamp_pre, dfg) in enumerate(dfrb_filt.groupby("nsamp_tra")):
    # ax.plot(dfg["nsamp_pre"], dfg[f"target_test_{metric}_mean"], label=f'train_samp={dfg["nsamp_tra"].unique()[0]}', c=colors[i])
    ax.errorbar(dfg["nsamp_pre"], dfg[f"target_test_{metric}_mean"], yerr=dfg[f"target_test_{metric}_std"], 
                label=f'train_samp={dfg["nsamp_tra"].unique()[0]}', c=colors[i])
    # ax.fill_between(dfg["nsamp_pre"], y1=dfg[f"target_test_{metric}_mean"]+dfg[f"target_test_{metric}_std"], 
    #  y2=dfg[f"target_test_{metric}_mean"]-dfg[f"target_test_{metric}_std"], alpha = 0.5, color=colors[i])

ax.plot(dfrb_filt["nsamp_pre"].unique(), dfrb_filt.groupby("nsamp_pre")[f"target_test_{metric}_mean"].mean(), label="TREND", c="black", lw=6)
plt.legend()
plt.grid(True)
plt.xlabel("pretrain samples")
plt.ylabel(metric)

print("general improvement:", dfrb_filt[f"target_test_{metric}_mean"].mean())
dfrb_filt.groupby("nsamp_pre")[f"target_test_{metric}_mean"].mean()
# Out:
# general improvement: 0.004176115989685049
# nsamp_pre
# 3627    -0.008867
# 7254    -0.004054
# 10881    0.008807
# 14508    0.011345
# 18135    0.013649
# Name: target_test_acc_mean, dtype: float64

# %%
df = aux.load_data(Path("results_synced/quantiles/"))
df
# Out:
#      dataset     arch  pretrained  fold_number  random_state  batch_size  \
# 0   GunPoint  CNN_DFS       False            0             0         128
# 1   GunPoint  CNN_DFS        True            0             0         128
# 2   GunPoint  CNN_DFS        True            0             0         128
# 3   GunPoint  CNN_DFS        True            0             0         128
# 4   GunPoint  CNN_DFS        True            0             0         128
# 5   GunPoint  CNN_DFS       False            3             0         128
# 6   GunPoint  CNN_DFS        True            3             0         128
# 7   GunPoint  CNN_DFS        True            3             0         128
# 8   GunPoint  CNN_DFS        True            3             0         128
# 9   GunPoint  CNN_DFS        True            3             0         128
# 10    Coffee  CNN_DFS       False            0             0         128
# 11    Coffee  CNN_DFS        True            0             0         128
# 12    Coffee  CNN_DFS        True            0             0         128
# 13    Coffee  CNN_DFS        True            0             0         128
# 14    Coffee  CNN_DFS        True            0             0         128
# 15  GunPoint  CNN_DFS       False            1             0         128
# 16  GunPoint  CNN_DFS        True            1             0         128
# 17  GunPoint  CNN_DFS        True            1             0         128
# 18  GunPoint  CNN_DFS        True            1             0         128
# 19  GunPoint  CNN_DFS        True            1             0         128
# 20  GunPoint  CNN_DFS       False            4             0         128
# 21  GunPoint  CNN_DFS        True            4             0         128
# 22  GunPoint  CNN_DFS        True            4             0         128
# 23  GunPoint  CNN_DFS        True            4             0         128
# 24  GunPoint  CNN_DFS        True            4             0         128
# 25    Coffee  CNN_DFS       False            3             0         128
# 26    Coffee  CNN_DFS        True            3             0         128
# 27    Coffee  CNN_DFS        True            3             0         128
# 28    Coffee  CNN_DFS        True            3             0         128
# 29    Coffee  CNN_DFS        True            3             0         128
# 30    Coffee  CNN_DFS       False            2             0         128
# 31    Coffee  CNN_DFS        True            2             0         128
# 32    Coffee  CNN_DFS        True            2             0         128
# 33    Coffee  CNN_DFS        True            2             0         128
# 34    Coffee  CNN_DFS        True            2             0         128
# 35  GunPoint  CNN_DFS       False            2             0         128
# 36  GunPoint  CNN_DFS        True            2             0         128
# 37  GunPoint  CNN_DFS        True            2             0         128
# 38  GunPoint  CNN_DFS        True            2             0         128
# 39  GunPoint  CNN_DFS        True            2             0         128
# 40    Coffee  CNN_DFS       False            1             0         128
# 41    Coffee  CNN_DFS        True            1             0         128
# 42    Coffee  CNN_DFS        True            1             0         128
# 43    Coffee  CNN_DFS        True            1             0         128
# 44    Coffee  CNN_DFS        True            1             0         128
#
#     window_size  target_val_acc  target_val_f1  target_val_auroc  ...  \
# 0             5        0.768066       0.768066          0.831575  ...
# 1             5        0.771973       0.771973          0.836356  ...
# 2             5        0.771484       0.771484          0.828854  ...
# 3             5        0.694336       0.694336          0.767606  ...
# 4             5        0.753906       0.753906          0.810815  ...
# 5             5        0.603516       0.603516          0.676341  ...
# 6             5        0.595215       0.595215          0.652723  ...
# 7             5        0.589355       0.589355          0.657601  ...
# 8             5        0.705566       0.705566          0.740593  ...
# 9             5        0.628906       0.628906          0.605455  ...
# 10            5        0.667188       0.667188          0.612609  ...
# 11            5        0.768750       0.768750          0.778225  ...
# 12            5        0.616406       0.616406          0.689690  ...
# 13            5        0.760938       0.760938          0.795790  ...
# 14            5        0.747656       0.747656          0.783816  ...
# 15            5        0.629883       0.629883          0.701988  ...
# 16            5        0.684082       0.684082          0.762213  ...
# 17            5        0.662598       0.662598          0.692677  ...
# 18            5        0.664062       0.664062          0.690464  ...
# 19            5        0.684570       0.684570          0.748681  ...
# 20            5        0.709473       0.709473          0.752978  ...
# 21            5        0.672363       0.672363          0.665287  ...
# 22            5        0.696289       0.696289          0.685375  ...
# 23            5        0.697266       0.697266          0.702529  ...
# 24            5        0.664062       0.664062          0.655702  ...
# 25            5        0.487500       0.487500          0.508972  ...
# 26            5        0.750000       0.750000          0.749235  ...
# 27            5        0.711719       0.711719          0.689633  ...
# 28            5        0.529688       0.529688          0.520495  ...
# 29            5        0.678906       0.678906          0.672028  ...
# 30            5        0.503906       0.503906          0.534909  ...
# 31            5        0.692187       0.692187          0.768437  ...
# 32            5        0.546094       0.546094          0.586146  ...
# 33            5        0.624219       0.624219          0.649381  ...
# 34            5        0.696094       0.696094          0.729281  ...
# 35            5        0.729980       0.729980          0.767604  ...
# 36            5        0.775391       0.775391          0.773407  ...
# 37            5        0.749512       0.749512          0.768252  ...
# 38            5        0.693848       0.693848          0.662984  ...
# 39            5        0.730957       0.730957          0.732926  ...
# 40            5        0.575000       0.575000          0.547914  ...
# 41            5        0.583594       0.583594          0.648512  ...
# 42            5        0.551562       0.551562          0.612598  ...
# 43            5        0.551562       0.551562          0.586129  ...
# 44            5        0.475000       0.475000          0.455449  ...
#
#     nsamp_tra  nsamp_pre  nsamp_test pretrain_nquant pretrain_val_acc  \
# 0        6135          0        5985             NaN              NaN
# 1        6135      18135        5985             3.0         0.911735
# 2        6135      18135        5985             5.0         0.884309
# 3        6135      18135        5985             7.0         0.816988
# 4        6135      18135        5985             9.0         0.782580
# 5        6135          0        5985             NaN              NaN
# 6        6135      18135        5985             3.0         0.909574
# 7        6135      18135        5985             5.0         0.850066
# 8        6135      18135        5985             7.0         0.814328
# 9        6135      18135        5985             9.0         0.725565
# 10       3417          0        3417             NaN              NaN
# 11       3417       9709        3417             3.0         0.942007
# 12       3417       9709        3417             5.0         0.872296
# 13       3417       9709        3417             7.0         0.851863
# 14       3417       9709        3417             9.0         0.647536
# 15       6135          0        5985             NaN              NaN
# 16       6135      18135        5985             3.0         0.910073
# 17       6135      18135        5985             5.0         0.893949
# 18       6135      18135        5985             7.0         0.842919
# 19       6135      18135        5985             9.0         0.765126
# 20       6135          0        5985             NaN              NaN
# 21       6135      18135        5985             3.0         0.917553
# 22       6135      18135        5985             5.0         0.865359
# 23       6135      18135        5985             7.0         0.789062
# 24       6135      18135        5985             9.0         0.782912
# 25       3417          0        3131             NaN              NaN
# 26       3417       9995        3131             3.0         0.942708
# 27       3417       9995        3131             5.0         0.874421
# 28       3417       9995        3131             7.0         0.862847
# 29       3417       9995        3131             9.0         0.643519
# 30       3417          0        3131             NaN              NaN
# 31       3417       9995        3131             3.0         0.950810
# 32       3417       9995        3131             5.0         0.875289
# 33       3417       9995        3131             7.0         0.880208
# 34       3417       9995        3131             9.0         0.782697
# 35       6135          0        5985             NaN              NaN
# 36       6135      18135        5985             3.0         0.918218
# 37       6135      18135        5985             5.0         0.895778
# 38       6135      18135        5985             7.0         0.817985
# 39       6135      18135        5985             9.0         0.751662
# 40       3417          0        3131             NaN              NaN
# 41       3417       9995        3131             3.0         0.952257
# 42       3417       9995        3131             5.0         0.871528
# 43       3417       9995        3131             7.0         0.880498
# 44       3417       9995        3131             9.0         0.741319
#
#     pretrain_val_f1  pretrain_val_auroc  \
# 0               NaN                 NaN
# 1          0.911735            0.984602
# 2          0.884309            0.977935
# 3          0.816988            0.967523
# 4          0.782580            0.972851
# 5               NaN                 NaN
# 6          0.909574            0.976117
# 7          0.850066            0.966855
# 8          0.814328            0.963814
# 9          0.725565            0.957279
# 10              NaN                 NaN
# 11         0.942007            0.990023
# 12         0.872296            0.958019
# 13         0.851863            0.969573
# 14         0.647536            0.850638
# 15              NaN                 NaN
# 16         0.910073            0.982119
# 17         0.893949            0.983404
# 18         0.842919            0.975032
# 19         0.765126            0.966317
# 20              NaN                 NaN
# 21         0.917553            0.982521
# 22         0.865359            0.972397
# 23         0.789062            0.961168
# 24         0.782912            0.968302
# 25              NaN                 NaN
# 26         0.942708            0.987381
# 27         0.874421            0.967721
# 28         0.862847            0.970286
# 29         0.643519            0.816752
# 30              NaN                 NaN
# 31         0.950810            0.991674
# 32         0.875289            0.965280
# 33         0.880208            0.979067
# 34         0.782697            0.951171
# 35              NaN                 NaN
# 36         0.918218            0.980956
# 37         0.895778            0.977425
# 38         0.817985            0.967794
# 39         0.751662            0.958739
# 40              NaN                 NaN
# 41         0.952257            0.993046
# 42         0.871528            0.957789
# 43         0.880498            0.975631
# 44         0.741319            0.930080
#
#                                   pretrain_best_model  \
# 0                                                 NaN
# 1   training/exp/EXP_quant_f0.0_2023-03-08_11-21/l...
# 2   training/exp/EXP_quant_f0.1_2023-03-08_11-27/l...
# 3   training/exp/EXP_quant_f0.2_2023-03-08_11-33/l...
# 4   training/exp/EXP_quant_f0.3_2023-03-08_11-40/l...
# 5                                                 NaN
# 6   training/exp/EXP_quant_f3.0_2023-03-08_12-47/l...
# 7   training/exp/EXP_quant_f3.1_2023-03-08_12-53/l...
# 8   training/exp/EXP_quant_f3.2_2023-03-08_13-00/l...
# 9   training/exp/EXP_quant_f3.3_2023-03-08_13-06/l...
# 10                                                NaN
# 11  training/exp/EXP_quant_f0.0_2023-03-08_13-46/l...
# 12  training/exp/EXP_quant_f0.1_2023-03-08_13-51/l...
# 13  training/exp/EXP_quant_f0.2_2023-03-08_13-55/l...
# 14  training/exp/EXP_quant_f0.3_2023-03-08_14-00/l...
# 15                                                NaN
# 16  training/exp/EXP_quant_f1.0_2023-03-08_11-49/l...
# 17  training/exp/EXP_quant_f1.1_2023-03-08_11-55/l...
# 18  training/exp/EXP_quant_f1.2_2023-03-08_12-02/l...
# 19  training/exp/EXP_quant_f1.3_2023-03-08_12-08/l...
# 20                                                NaN
# 21  training/exp/EXP_quant_f4.0_2023-03-08_13-16/l...
# 22  training/exp/EXP_quant_f4.1_2023-03-08_13-23/l...
# 23  training/exp/EXP_quant_f4.2_2023-03-08_13-30/l...
# 24  training/exp/EXP_quant_f4.3_2023-03-08_13-36/l...
# 25                                                NaN
# 26  training/exp/EXP_quant_f3.0_2023-03-08_15-00/l...
# 27  training/exp/EXP_quant_f3.1_2023-03-08_15-06/l...
# 28  training/exp/EXP_quant_f3.2_2023-03-08_15-13/l...
# 29  training/exp/EXP_quant_f3.3_2023-03-08_15-19/l...
# 30                                                NaN
# 31  training/exp/EXP_quant_f2.0_2023-03-08_14-33/l...
# 32  training/exp/EXP_quant_f2.1_2023-03-08_14-38/l...
# 33  training/exp/EXP_quant_f2.2_2023-03-08_14-44/l...
# 34  training/exp/EXP_quant_f2.3_2023-03-08_14-50/l...
# 35                                                NaN
# 36  training/exp/EXP_quant_f2.0_2023-03-08_12-18/l...
# 37  training/exp/EXP_quant_f2.1_2023-03-08_12-24/l...
# 38  training/exp/EXP_quant_f2.2_2023-03-08_12-30/l...
# 39  training/exp/EXP_quant_f2.3_2023-03-08_12-37/l...
# 40                                                NaN
# 41  training/exp/EXP_quant_f1.0_2023-03-08_14-08/l...
# 42  training/exp/EXP_quant_f1.1_2023-03-08_14-13/l...
# 43  training/exp/EXP_quant_f1.2_2023-03-08_14-18/l...
# 44  training/exp/EXP_quant_f1.3_2023-03-08_14-24/l...
#
#                                    pretrain_train_csv  pretrain_nepochs
# 0                                                 NaN               NaN
# 1   training/exp/EXP_quant_f0.0_2023-03-08_11-21/l...              60.0
# 2   training/exp/EXP_quant_f0.1_2023-03-08_11-27/l...              60.0
# 3   training/exp/EXP_quant_f0.2_2023-03-08_11-33/l...              60.0
# 4   training/exp/EXP_quant_f0.3_2023-03-08_11-40/l...              60.0
# 5                                                 NaN               NaN
# 6   training/exp/EXP_quant_f3.0_2023-03-08_12-47/l...              60.0
# 7   training/exp/EXP_quant_f3.1_2023-03-08_12-53/l...              60.0
# 8   training/exp/EXP_quant_f3.2_2023-03-08_13-00/l...              60.0
# 9   training/exp/EXP_quant_f3.3_2023-03-08_13-06/l...              60.0
# 10                                                NaN               NaN
# 11  training/exp/EXP_quant_f0.0_2023-03-08_13-46/l...              60.0
# 12  training/exp/EXP_quant_f0.1_2023-03-08_13-51/l...              60.0
# 13  training/exp/EXP_quant_f0.2_2023-03-08_13-55/l...              60.0
# 14  training/exp/EXP_quant_f0.3_2023-03-08_14-00/l...              60.0
# 15                                                NaN               NaN
# 16  training/exp/EXP_quant_f1.0_2023-03-08_11-49/l...              60.0
# 17  training/exp/EXP_quant_f1.1_2023-03-08_11-55/l...              60.0
# 18  training/exp/EXP_quant_f1.2_2023-03-08_12-02/l...              60.0
# 19  training/exp/EXP_quant_f1.3_2023-03-08_12-08/l...              60.0
# 20                                                NaN               NaN
# 21  training/exp/EXP_quant_f4.0_2023-03-08_13-16/l...              60.0
# 22  training/exp/EXP_quant_f4.1_2023-03-08_13-23/l...              60.0
# 23  training/exp/EXP_quant_f4.2_2023-03-08_13-30/l...              60.0
# 24  training/exp/EXP_quant_f4.3_2023-03-08_13-36/l...              60.0
# 25                                                NaN               NaN
# 26  training/exp/EXP_quant_f3.0_2023-03-08_15-00/l...              60.0
# 27  training/exp/EXP_quant_f3.1_2023-03-08_15-06/l...              60.0
# 28  training/exp/EXP_quant_f3.2_2023-03-08_15-13/l...              60.0
# 29  training/exp/EXP_quant_f3.3_2023-03-08_15-19/l...              60.0
# 30                                                NaN               NaN
# 31  training/exp/EXP_quant_f2.0_2023-03-08_14-33/l...              60.0
# 32  training/exp/EXP_quant_f2.1_2023-03-08_14-38/l...              60.0
# 33  training/exp/EXP_quant_f2.2_2023-03-08_14-44/l...              60.0
# 34  training/exp/EXP_quant_f2.3_2023-03-08_14-50/l...              60.0
# 35                                                NaN               NaN
# 36  training/exp/EXP_quant_f2.0_2023-03-08_12-18/l...              60.0
# 37  training/exp/EXP_quant_f2.1_2023-03-08_12-24/l...              60.0
# 38  training/exp/EXP_quant_f2.2_2023-03-08_12-30/l...              60.0
# 39  training/exp/EXP_quant_f2.3_2023-03-08_12-37/l...              60.0
# 40                                                NaN               NaN
# 41  training/exp/EXP_quant_f1.0_2023-03-08_14-08/l...              60.0
# 42  training/exp/EXP_quant_f1.1_2023-03-08_14-13/l...              60.0
# 43  training/exp/EXP_quant_f1.2_2023-03-08_14-18/l...              60.0
# 44  training/exp/EXP_quant_f1.3_2023-03-08_14-24/l...              60.0
#
# [45 rows x 26 columns]

# %%
metric = "acc"
arch = "CNN_DFS"
dataset = "GunPoint"

data_mean = df[df["dataset"] == dataset][df["arch"] == arch].replace(np.NaN, 0).groupby(["arch", "dataset", "pretrain_nquant"])[f"target_test_{metric}"].mean()
data_std = df[df["dataset"] == dataset][df["arch"] == arch].replace(np.NaN, 0).groupby(["arch", "dataset", "pretrain_nquant"])[f"target_test_{metric}"].std()
data_mean = (data_mean - data_mean.iloc[0]).reset_index()
data_std = data_std.reset_index()

fig, ax = plt.subplots(figsize=[12,8])
ax.errorbar(data_mean["pretrain_nquant"], data_mean[f"target_test_{metric}"], yerr=data_std[f"target_test_{metric}"]);
