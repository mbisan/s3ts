# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("time_series_data_human_activities.csv")
df
# Out:
#          user  activity       timestamp  x-axis  y-axis    z-axis
# 0           1   Walking   4991922345000    0.69   10.80 -2.030000
# 1           1   Walking   4991972333000    6.85    7.44 -0.500000
# 2           1   Walking   4992022351000    0.93    5.63 -0.500000
# 3           1   Walking   4992072339000   -2.11    5.01 -0.690000
# 4           1   Walking   4992122358000   -4.59    4.29 -1.950000
# ...       ...       ...             ...     ...     ...       ...
# 1073618    36  Standing  15049012250000   -0.91    9.43  2.533385
# 1073619    36  Standing  15049062268000   -1.18    9.51  2.492524
# 1073620    36  Standing  15049112287000   -1.50    9.53  2.533385
# 1073621    36  Standing  15049162275000   -2.07    8.77  2.179256
# 1073622    36  Standing  15049212262000   -2.14    9.89  3.255263
#
# [1073623 rows x 6 columns]

# %%
user = df[df["user"] == 3][["activity", "x-axis","y-axis","z-axis"]]

# %%
user.activity.unique()
# Out:
# array(['Walking', 'Jogging', 'Sitting', 'Standing', 'Upstairs',
#        'Downstairs'], dtype=object)

# %%
user[user["activity"] == 'Walking'].iloc[50:100].plot()
# Out:
# <Axes: >

# %%
user[user["activity"] == 'Jogging'].iloc[50:100].plot()
# Out:
# <Axes: >

# %%
user[user["activity"] == 'Upstairs'].iloc[50:100].plot()
# Out:
# <Axes: >

# %%
user.loc[0:200].plot()
# Out:
# <Axes: >

# %%
# make all users start at timestamp 0

dfl = []
for user, udf in df.groupby("user"):
    udf["timestamp"] = udf["timestamp"] - udf["timestamp"].min()
    dfl.append(udf)

df = pd.concat(dfl)

# %%
df
# Out:
#          user  activity      timestamp  x-axis  y-axis    z-axis
# 0           1   Walking              0    0.69   10.80 -2.030000
# 1           1   Walking       49988000    6.85    7.44 -0.500000
# 2           1   Walking      100006000    0.93    5.63 -0.500000
# 3           1   Walking      149994000   -2.11    5.01 -0.690000
# 4           1   Walking      200013000   -4.59    4.29 -1.950000
# ...       ...       ...            ...     ...     ...       ...
# 1073618    36  Standing  1989669952000   -0.91    9.43  2.533385
# 1073619    36  Standing  1989719970000   -1.18    9.51  2.492524
# 1073620    36  Standing  1989769989000   -1.50    9.53  2.533385
# 1073621    36  Standing  1989819977000   -2.07    8.77  2.179256
# 1073622    36  Standing  1989869964000   -2.14    9.89  3.255263
#
# [1073623 rows x 6 columns]
